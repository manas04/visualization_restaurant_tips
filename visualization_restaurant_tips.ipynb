# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips.head() #describing first five rows of dataset
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.day.unique() #describing number of unique days in dataset
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Sun', 'Sat', 'Thur', 'Fri']

# %%
tips.time.unique()  #describing number of unique times customer visit at hotel
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Dinner', 'Lunch']

# %%
tips.tail() #describing last 5 rows of the dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.time.value_counts()  #counts distict number of lunches and dinners in the dataset
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
tips.time.value_counts().plot()

# %%
tips.time.value_counts().plot(kind='bar') #bargraph representing lunch and dinner in dataset

# %%
tips.time.value_counts(normalize=True)  #percentage of lunch and dinner
# Out:
# Dinner    0.721311
# Lunch     0.278689
# Name: time, dtype: float64

# %%
tips.groupby(['time'])['tip'].mean()
# Out:
# time
# Lunch     2.728088
# Dinner    3.102670
# Name: tip, dtype: float64

# %%
tips.groupby(['time'])['tip'].mean().plot.bar()

# %%
tips.groupby(['sex'])['tip'].mean()
# Out:
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
tips.groupby(['smoker'])['tip'].mean()
# Out:
# smoker
# Yes    3.008710
# No     2.991854
# Name: tip, dtype: float64

# %%
tips.groupby(['size'])['tip'].mean()
# Out:
# size
# 1    1.437500
# 2    2.582308
# 3    3.393158
# 4    4.135405
# 5    4.028000
# 6    5.225000
# Name: tip, dtype: float64

# %%
tips.groupby(['day'])['tip'].mean()
# Out:
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %%
tips.groupby(['sex','smoker'])['tip'].mean()
# Out:
# sex     smoker
# Male    Yes       3.051167
#         No        3.113402
# Female  Yes       2.931515
#         No        2.773519
# Name: tip, dtype: float64

# %%
tips.groupby(['sex','smoker'])['tip'].mean().unstack()
# Out:
# smoker       Yes        No
# sex
# Male    3.051167  3.113402
# Female  2.931515  2.773519

# %%
tips.groupby(['smoker','day'])['tip'].mean().unstack()
# Out:
# day         Thur     Fri       Sat       Sun
# smoker
# Yes     3.030000  2.7140  2.875476  3.516842
# No      2.673778  2.8125  3.102889  3.167895

# %%
tips.groupby(['size','day'])['tip'].mean().unstack()
# Out:
# day     Thur       Fri       Sat       Sun
# size
# 1     1.8300  1.920000  1.000000       NaN
# 2     2.4425  2.644375  2.517547  2.816923
# 3     2.6925  3.000000  3.797778  3.120667
# 4     4.2180  4.730000  4.123846  4.087778
# 5     5.0000       NaN  3.000000  4.046667
# 6     5.3000       NaN       NaN  5.000000

# %%
tips['tips_percentage'] = tips.tip/tips.total_bill

# %%
tips['tips_percentage'].head()
# Out:
# 0    0.059447
# 1    0.160542
# 2    0.166587
# 3    0.139780
# 4    0.146808
# Name: tips_percentage, dtype: float64

# %%
tips.plot.scatter(x='total_bill',y='tip')

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips)

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='time')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,col="sex",hue="time")

# %%
sns.displot(data=tips,x="total_bill",col="time",kde=True)

# %%
sns.displot(data=tips,x="tip",col="time",kde=True)

# %%
sns.pairplot(data=tips,hue="sex")
